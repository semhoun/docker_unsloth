# %% [markdown]
# <a href="https://colab.research.google.com/github/semhoun/omnius/blob/main/nb/Claire.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Acknowledgments
# <div class="align-center">
# <a href="https://unsloth.ai/"><img src="https://github.com/unslothai/unsloth/raw/main/images/unsloth%20new%20logo.png" width="115"></a>
# <a href="https://discord.gg/unsloth"><img src="https://github.com/unslothai/unsloth/raw/main/images/Discord button.png" width="145"></a>
# <a href="https://docs.unsloth.ai/"><img src="https://github.com/unslothai/unsloth/blob/main/images/documentation%20green%20button.png?raw=true" width="125"></a> <a href="https://github.com/unslothai/unsloth"><img src="https://github.githubassets.com/assets/GitHub-Mark-ea2971cee799.png" width="43"></a>
# </div>
#
# # Data Sources:
# * https://huggingface.co/angeluriot
# * https://huggingface.co/CATIE-AQ
# * https://huggingface.co/jpacifico
# * https://huggingface.co/OpenLLM-France

# %% [markdown]
# # Params

# %%
import os

if "UNSLOTH_DOCKER" in "".join(os.environ.keys()):
  hf_token = os.environ["HUGGINGFACE_TOKEN"]
  hf_username = os.environ["HUGGINGFACE_USERNAME"]
elif "COLAB_" in "".join(os.environ.keys()):
  from google.colab import userdata
  hf_token = userdata.get('HuggingFaceToken')
  hf_username = userdata.get('HuggingFaceUsername')
else:
  hf_token = os.environ["HUGGINGFACE_TOKEN"]
  hf_username = os.environ["HUGGINGFACE_USERNAME"]

debug = True
save_hf = False
local_llama = "LLAMACPP_PATH" in "".join(os.environ.keys())
dataset_processors = 8

source_model = "HuggingFaceTB/SmolLM3-3B-Base"
quantizations = ["q8_0", "q4_k_m "]
model_name = "Claire-3B-v0.2.0"

# %% [markdown]
# # Installation

# %%
# %%capture
import os, re

if "UNSLOTH_DOCKER" in "".join(os.environ.keys()):
  # Docker Unsloth version
  pass
if "COLAB_" in "".join(os.environ.keys()):
  os.environ["PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION"] = "python"
  # Google colab
  import torch; v = re.match(r"[0-9\.]{3,}", str(torch.__version__)).group(0)
  xformers = "xformers==" + ("0.0.32.post2" if v == "2.8.0" else "0.0.29.post3")
  # !pip install --upgrade --no-deps bitsandbytes accelerate {xformers} peft trl triton cut_cross_entropy unsloth_zoo
  # !pip install sentencepiece protobuf "datasets>=3.4.1,<4.0.0" "huggingface_hub>=0.34.0" hf_transfer
  # !pip install --no-deps --upgrade unsloth
  # !pip install transformers==4.55.4
  # !pip install --no-deps trl==0.22.2
else:
  os.environ["PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION"] = "python"
  # !pip install --upgrade unsloth-zoo
  # !pip install --upgrade unsloth
  # !pip install transformers==4.55.4
  # !pip install --no-deps trl==0.22.2

# %% [markdown]
# # Unsloth

# %% [markdown]
# ## Model download

# %%
from unsloth import FastLanguageModel
import torch
max_seq_length = 2048 # Choose any! We auto support RoPE Scaling internally!
dtype = None # None for auto detection. Float16 for Tesla T4, V100, Bfloat16 for Ampere+

model, tokenizer = FastLanguageModel.from_pretrained(
    model_name = source_model,
    max_seq_length = max_seq_length,
    dtype = dtype,
    load_in_4bit = False,
    load_in_8bit = False,
    token = hf_token,
)
# Out:
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# INFO 09-30 12:18:06 [__init__.py:241] Automatically detected platform cuda.
# 🦥 Unsloth Zoo will now patch everything to make training faster!
# ==((====))==  Unsloth 2025.9.9: Fast Smollm3 patching. Transformers: 4.56.2. vLLM: 0.10.1.
#    \\   /|    NVIDIA GeForce RTX 3060. Num GPUs = 1. Max memory: 11.629 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.7.1+cu128. CUDA: 8.6. CUDA Toolkit: 12.8. Triton: 3.3.1
# \        /    Bfloat16 = TRUE. FA [Xformers = 0.0.31. FA2 = False]
#  "-____-"     Free license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# Unsloth: QLoRA and full finetuning all not selected. Switching to 16bit LoRA.
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# Fetching 2 files:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/1.18G [00:00<?, ?B/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/4.97G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/126 [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.2M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/151 [00:00<?, ?B/s]
# HuggingFaceTB/SmolLM3-3B-Base does not have a padding token! Will use pad_token = <|finetune_right_pad_id|>.

# %% [markdown]
# ## LoRA
# Add LoRA adapters so we only need to update 1 to 10% of all parameters!

# %%
from unsloth import FastModel

lora_rank = 16 # Choose any number > 0 ! Suggested 8, 16, 32, 64, 128

model = FastLanguageModel.get_peft_model(
    model,
    r = lora_rank,
    target_modules = [
      "q_proj", "k_proj", "v_proj", "o_proj",
      "gate_proj", "up_proj", "down_proj"
      "embed_tokens", "lm_head", # Add for continual pretraining, it seem to be replaced by module_to_save
    ],
    modules_to_save=["embed_tokens", "lm_head"],
    lora_alpha = lora_rank,
    lora_dropout = 0, # Supports any, but = 0 is optimized
    bias = "none",    # Supports any, but = "none" is optimized
    use_gradient_checkpointing = "unsloth", # True or "unsloth" for very long context
    random_state = 3407,
    use_rslora = False,  # We support rank stabilized LoRA
    loftq_config = None, # And LoftQ
)
# Out:
# Unsloth: Making `model.base_model.model.model.embed_tokens` require gradients
# Unsloth: Allowing gradients for `base_model.model.model.embed_tokens` since it's in `modules_to_save`.
# Unsloth: Allowing gradients for `base_model.model.lm_head` since it's in `modules_to_save`.

# %% [markdown]
# # Tools

# %% [markdown]
# ## Dataset formatter
# **[NOTE]** Remember to add the **EOS_TOKEN** to the tokenized output!! Otherwise you'll get infinite generations!
#
# ChatML renders multi turn conversations like below:
#
# ```
# <|im_start|>system
# You are a helpful assistant.<|im_end|>
# <|im_start|>user
# What's the capital of France?<|im_end|>
# <|im_start|>assistant
# Paris.
# ```
#
# We use our `get_chat_template` function to get the correct chat template. We support `zephyr, chatml, mistral, llama, alpaca, vicuna, vicuna_old` and our own optimized `unsloth` template.
#
# Normally one has to train `<|im_start|>` and `<|im_end|>`. We instead map `<|im_end|>` to be the EOS token, and leave `<|im_start|>` as is. This requires no additional training of additional tokens.
#
# More info on chat templates on [our wiki page!](https://github.com/unslothai/unsloth/wiki#chat-templates)
#
# For text completions like novel writing, try this [notebook](https://colab.research.google.com/drive/1ef-tab5bhkvWmBOObepl1WgJvfvSzn5Q?usp=sharing).

# %%
#@title Base Prompt
wikipedia_prompt = """{} Article
### Title: {}

### Article:
{}"""

ebook_prompt = """Book
### Title: {}

### Author: {}

### Content:
{}"""

# %%
#@title SmallLm ChatML
smollm_chatml = """{#  ───── defaults ─────  #}
{%- if enable_thinking is not defined -%}
	{%- set enable_thinking = true -%}
{%- endif -%}
{#  ───── reasoning mode ─────  #}
{%- if enable_thinking -%}
	{%- set reasoning_mode = "/think" -%}
{%- else -%}
	{%- set reasoning_mode = "/no_think" -%}
{%- endif -%}
{#  ───── header (system message) ─────  #}
{{- "<|im_start|>system\n" -}}
{%- if messages[0].role == "system" -%}
	{%- set system_message = messages[0].content -%}
	{%- if "/no_think" in system_message -%}
		{%- set reasoning_mode = "/no_think" -%}
	{%- elif "/think" in system_message -%}
		{%- set reasoning_mode = "/think" -%}
	{%- endif -%}
	{%- set custom_instructions = system_message.replace("/no_think", "").replace("/think", "").rstrip() -%}
{%- endif -%}
{%- if "/system_override" in system_message -%}
	{{- custom_instructions.replace("/system_override", "").rstrip() -}}
	{{- "<|im_end|>\n" -}}
{%- else -%}
	{{- "## Metadata\n\n" -}}
	{{- "Knowledge Cutoff Date: June 2025\n" -}}
	{%- set today = strftime_now("%d %B %Y") -%}
	{{- "Today Date: " ~ today ~ "\n" -}}
	{{- "Reasoning Mode: " + reasoning_mode + "\n\n" -}}
	{{- "## Custom Instructions\n\n" -}}
	{%- if custom_instructions -%}
		{{- custom_instructions + "\n\n" -}}
	{%- elif reasoning_mode == "/think" -%}
		{{- "You are a helpful AI assistant named SmolLM, trained by Hugging Face. Your role as an assistant involves thoroughly exploring questions through a systematic thinking process before providing the final precise and accurate solutions. This requires engaging in a comprehensive cycle of analysis, summarizing, exploration, reassessment, reflection, backtracking, and iteration to develop well-considered thinking process. Please structure your response into two main sections: Thought and Solution using the specified format: <think> Thought section </think> Solution section. In the Thought section, detail your reasoning process in steps. Each step should include detailed considerations such as analysing questions, summarizing relevant findings, brainstorming new ideas, verifying the accuracy of the current steps, refining any errors, and revisiting previous steps. In the Solution section, based on various attempts, explorations, and reflections from the Thought section, systematically present the final solution that you deem correct. The Solution section should be logical, accurate, and concise and detail necessary steps needed to reach the conclusion.\n\n" -}}
	{%- else -%}
		{{- "You are a helpful AI assistant named SmolLM, trained by Hugging Face.\n\n" -}}
	{%- endif -%}
	{%- if xml_tools or python_tools or tools -%}
		{{- "### Tools\n\n" -}}
		{%- if xml_tools or tools -%}
			{%- if tools -%}
				{%- set xml_tools = tools -%}
			{%- endif -%}
			{%- set ns = namespace(xml_tool_string="You may call one or more functions to assist with the user query.\nYou are provided with function signatures within <tools></tools> XML tags:\n\n<tools>\n") -%}
			{%- for tool in xml_tools[:] -%}
				{#  The slicing makes sure that xml_tools is a list  #}
				{%- set ns.xml_tool_string = ns.xml_tool_string ~ tool | string ~ "\n" -%}
			{%- endfor -%}
			{%- set xml_tool_string = ns.xml_tool_string + "</tools>\n\nFor each function call, return a json object with function name and arguments within <tool_call></tool_call> XML tags:\n<tool_call>\n{" + '"' + "name" + '"' + ": <function-name>, " + '"' + "arguments" + '"' + ": <args-json-object>}\n</tool_call>" -%}
			{{- xml_tool_string -}}
		{%- endif -%}
		{%- if python_tools -%}
			{%- set ns = namespace(python_tool_string="When you send a message containing Python code between '<code>' and '</code>' tags, it will be executed in a stateful Jupyter notebook environment, and you will then be given the output to continued reasoning in an agentic loop.\n\nYou can use the following tools in your python code like regular functions:\n<tools>\n") -%}
			{%- for tool in python_tools[:] -%}
				{#  The slicing makes sure that python_tools is a list  #}
				{%- set ns.python_tool_string = ns.python_tool_string ~ tool | string ~ "\n" -%}
			{%- endfor -%}
			{%- set python_tool_string = ns.python_tool_string + "</tools>\n\nThe state persists between code executions: so variables that you define in one step are still available thereafter." -%}
			{{- python_tool_string -}}
		{%- endif -%}
		{{- "\n\n" -}}
		{{- "<|im_end|>\n" -}}
	{%- endif -%}
{%- endif -%}
{#  ───── main loop ─────  #}
{%- for message in messages -%}
	{%- set content = message.content if message.content is string else "" -%}
	{%- if message.role == "user" -%}
		{{- "<|im_start|>" + message.role + "\n" + content + "<|im_end|>\n" -}}
	{%- elif message.role == "assistant" -%}
		{%- if reasoning_mode == "/think" -%}
			{{- "<|im_start|>assistant\n" + content.lstrip("\n") + "<|im_end|>\n" -}}
		{%- else -%}
			{{- "<|im_start|>assistant\n" + "<think>\n\n</think>\n" + content.lstrip("\n") + "<|im_end|>\n" -}}
		{%- endif -%}
	{%- elif message.role == "tool" -%}
		{{- "<|im_start|>" + "user\n" + content + "<|im_end|>\n" -}}
	{%- endif -%}
{%- endfor -%}
{#  ───── generation prompt ─────  #}
{%- if add_generation_prompt -%}
	{%- if reasoning_mode == "/think" -%}
		{{- "<|im_start|>assistant\n" -}}
	{%- else -%}
		{{- "<|im_start|>assistant\n" + "<think>\n\n</think>\n" -}}
	{%- endif -%}
{%- endif -%}"""

# %%
#@title Prompt Formatter
import pprint, json

tokenizer.chat_template = smollm_chatml
EOS_TOKEN = tokenizer.eos_token

def format_sft(examples, thinking):
  # convos or messages
  for key in ("conversations", "conversation", "messages"):
    convos = examples.get(key)
    if convos is not None:
      break
  else:
    raise ValueError("Unknown sft data format.")

  # system and context
  for key in ("system", "context"):
    systems = examples.get(key)
    if systems is not None:
      # Special fix for context
      if (key == "context"):
        contexts = []
        for system in systems:
          contexts.append("Utilise le contexte entre <ctx> pour répondre. Si tu ne sais pas, dis-le.\n<ctx>\n" + system +"\n</ctx>")
        systems = contexts
      break
  else:
    systems = [""] * len(convos)

  if (examples.get('chat_template_kwargs') != None):
    kwargss = examples["chat_template_kwargs"]
  else:
    kwargss = [{'enable_thinking' : thinking}] * len(convos) # Corrected list creation

  outputs = []
  for system, convo, kwargs in zip(systems, convos, kwargss):
    messages = [{
      "role": "system",
      "content": system
    }]
    for row in convo:
      role = row.get('from') or row.get('role')
      if role is None:
        raise ValueError('Unknow role data format.')
      normalized_role = str(role).lower()
      if 'humain' in normalized_role:
        role = 'user'
      elif 'gpt' in normalized_role:
        role = 'assistant'
      else:
        role = normalized_role

      content = row.get('content') or row.get('text')
      if content is None:
          raise ValueError('Unknow role data format.')

      messages.append({
        "role": role,
        "content": content
      })
    outputs.append(tokenizer.apply_chat_template(
      messages,
      tokenize=False,
      add_generation_prompt=False,
      **kwargs
    ))
  return { "text" : outputs, }

def format_cpt_wikipedia(examples):
  sources = examples["source"]
  titles = examples["title"]
  texts  = examples["text"]
  outputs = []
  for source, title, text in zip(sources, titles, texts):
    text = wikipedia_prompt.format(source.title(),title, text) + EOS_TOKEN
    outputs.append(text)
  return { "text" : outputs, }

def format_cpt_ebook(examples):
  titles = examples["title"]
  authors = examples["author"]
  texts  = examples.get('text') or examples.get('content')
  outputs = []
  for title, author, text in zip(titles, authors, texts):
    author = json.loads(author)
    text = ebook_prompt.format(title, author['author'], text) + EOS_TOKEN
    outputs.append(text)
  return { "text" : outputs, }

def format_text(examples):
    return { "text" : [example + EOS_TOKEN for example in examples["text"]] }

def format_dpo(exemples, thinking):
  for key in ("question", "prompt"):
    prompts = examples.get(key)
    if prompts is not None:
      break
  else:
    raise ValueError("Unknown dpo data format.")

  for key in ("system", "context"):
    systems = examples.get(key)
    if systems is not None:
      break
  else:
    systems = [""] * len(prompts)

  chosens = examples.get('chosen')
  rejecteds = examples.get('rejected')

  outputs = {
      "prompt" : [],
      "chosen" : [],
      "rejected" : []
  }
  kwargs = [{'enable_thinking' : false}]
  for system, prompt, chosen, rejected in zip(systems, prompts, chosens, rejecteds):
    messages = [{
      "role": "system",
      "content": system
    }, {
      "role": "user",
      "content": prompt
    }]
    outputs["prompt"].append(tokenizer.apply_chat_template(prompt, tokenize=False, add_generation_prompt=True, **kwargs))
    outputs["chosen"].append(chosen + EOS_TOKEN)
    outputs["rejected"].append(rejected + EOS_TOKEN)
  return outputs

# Must add EOS_TOKEN, otherwise your generation will go on forever!
# batched=True is needed
def formatting_prompts_func(
    examples,
    task: "sft", # "sft", "cpt_wikipedia", "cpt_book", "text", "dpo"
    thinking = False):
  formatting_functions = {
      'sft': lambda exs: format_sft(exs, thinking),
      'cpt_wikipedia': format_cpt_wikipedia,
      'cpt_ebook': format_cpt_ebook,
      'dpo': lambda exs: format_dpo(exs, thinking),
      'text': format_text,
  }
  formatter = formatting_functions.get(task)
  if formatter:
      return formatter(examples)
  else:
      raise ValueError(f'Unknown task format: {task}')

# %% [markdown]
# ## Dataset helper

# %%
import random
from datasets import load_dataset
from datasets import concatenate_datasets
from datasets import Dataset

def dumpDatasets(datasets):
  for key, value in datasets.items():
    print('=' * 25 + ' ' + key.upper() + ' ' + '=' * 25)
    row = value[random.randrange(0, len(value), 1)]
    for rkey, rvalue in row.items():
      print('#' * 10 + ' ' + rkey.upper())
      pprint.pp(rvalue[:16384])
    print("\n\n")
pass

def mergeDatasets(datasets):
  resDataSet = Dataset.from_dict({})
  for key, value in datasets.items():
    if debug:
      value = value.train_test_split(train_size = 0.02)['train']
    resDataSet = concatenate_datasets([resDataSet, value])
  resDataSet = resDataSet.shuffle(seed=0)
  return resDataSet
pass

def loadDataset(url, task, subset = None, thinking = False, split = 'train'):
  if (subset != None):
    dataset = load_dataset(url, subset, split = split, token=hf_token)
  else:
    dataset = load_dataset(url, split = split, token=hf_token)
  dataset = dataset.map(formatting_prompts_func, batched = True, fn_kwargs= {'task':task, 'thinking': thinking})
  if (task == 'dpo'):
    dataset = dataset.select_columns(['prompt', 'chosen', 'rejected'])
  else:
    dataset = dataset.select_columns(['text'])
  return dataset

# %% [markdown]
# # Continued pre-training (CPT)

# %% [markdown]
# ## Datasets(s)

# %%
#@title Init datasets
datasets = {}

# %%
#@title EBook data
datasets['ebooks'] = loadDataset('nsemhoun/ebooks', 'cpt_ebook')
# Out:
# books.jsonl:   0%|          | 0.00/59.3M [00:00<?, ?B/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# Map:   0%|          | 0/101 [00:00<?, ? examples/s]
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# /tmp/ipython-input-1897679590.py in <cell line: 0>()
#       1 #@title EBook data
# ----> 2 datasets['ebooks'] = loadDataset('nsemhoun/ebooks_nsfw', 'cpt_ebook')
#
# /tmp/ipython-input-864439217.py in loadDataset(url, task, subset, thinking, split)
#      29   else:
#      30     dataset = load_dataset(url, split = split, token=hf_token)
# ---> 31   dataset = dataset.map(formatting_prompts_func, batched = True, fn_kwargs= {'task':task, 'thinking': thinking})
#      32   if (task == 'dpo'):
#      33     dataset = dataset.select_columns(['prompt', 'chosen', 'rejected'])
#
# /usr/local/lib/python3.12/dist-packages/datasets/arrow_dataset.py in wrapper(*args, **kwargs)
#     555         }
#     556         # apply actual function
# --> 557         out: Union["Dataset", "DatasetDict"] = func(self, *args, **kwargs)
#     558         datasets: list["Dataset"] = list(out.values()) if isinstance(out, dict) else [out]
#     559         # re-apply format to the output
#
# /usr/local/lib/python3.12/dist-packages/datasets/arrow_dataset.py in map(self, function, with_indices, with_rank, input_columns, batched, batch_size, drop_last_batch, remove_columns, keep_in_memory, load_from_cache_file, cache_file_name, writer_batch_size, features, disable_nullable, fn_kwargs, num_proc, suffix_template, new_fingerprint, desc, try_original_type)
#    3077                     desc=desc or "Map",
#    3078                 ) as pbar:
# -> 3079                     for rank, done, content in Dataset._map_single(**dataset_kwargs):
#    3080                         if done:
#    3081                             shards_done += 1
#
# /usr/local/lib/python3.12/dist-packages/datasets/arrow_dataset.py in _map_single(shard, function, with_indices, with_rank, input_columns, batched, batch_size, drop_last_batch, remove_columns, keep_in_memory, cache_file_name, writer_batch_size, features, disable_nullable, fn_kwargs, new_fingerprint, rank, offset, try_original_type)
#    3523                 else:
#    3524                     _time = time.time()
# -> 3525                     for i, batch in iter_outputs(shard_iterable):
#    3526                         num_examples_in_batch = len(i)
#    3527                         if update_data:
#
# /usr/local/lib/python3.12/dist-packages/datasets/arrow_dataset.py in iter_outputs(shard_iterable)
#    3473             else:
#    3474                 for i, example in shard_iterable:
# -> 3475                     yield i, apply_function(example, i, offset=offset)
#    3476
#    3477         num_examples_progress_update = 0
#
# /usr/local/lib/python3.12/dist-packages/datasets/arrow_dataset.py in apply_function(pa_inputs, indices, offset)
#    3396             """Utility to apply the function on a selection of columns."""
#    3397             inputs, fn_args, additional_args, fn_kwargs = prepare_inputs(pa_inputs, indices, offset=offset)
# -> 3398             processed_inputs = function(*fn_args, *additional_args, **fn_kwargs)
#    3399             return prepare_outputs(pa_inputs, inputs, processed_inputs)
#    3400
#
# /tmp/ipython-input-3383230708.py in formatting_prompts_func(examples, task, thinking)
#     167   formatter = formatting_functions.get(task)
#     168   if formatter:
# --> 169       return formatter(examples)
#     170   else:
#     171       raise ValueError(f'Unknown task format: {task}')
#
# /tmp/ipython-input-3383230708.py in format_cpt_ebook(examples)
#      87   outputs = []
#      88   for title, author, text in zip(titles, authors,  texts):
# ---> 89     author = json.loads(author)
#      90     text = ebook_prompt.format(title, author['author'], text) + EOS_TOKEN
#      91     outputs.append(text)
#
# /usr/lib/python3.12/json/__init__.py in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     344             parse_int is None and parse_float is None and
#     345             parse_constant is None and object_pairs_hook is None and not kw):
# --> 346         return _default_decoder.decode(s)
#     347     if cls is None:
#     348         cls = JSONDecoder
#
# /usr/lib/python3.12/json/decoder.py in decode(self, s, _w)
#     336
#     337         """
# --> 338         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     339         end = _w(s, end).end()
#     340         if end != len(s):
#
# /usr/lib/python3.12/json/decoder.py in raw_decode(self, s, idx)
#     354             obj, end = self.scan_once(s, idx)
#     355         except StopIteration as err:
# --> 356             raise JSONDecodeError("Expecting value", s, err.value) from None
#     357         return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %%
#@title Wikipedia data
datasets['wikipedia'] = loadDataset('OpenLLM-France/wikimedia', 'cpt_wikipedia', subset='fr')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 2
#       1 #@title Wikipedia data
# ----> 2 datasets['wikipedia'] = loadDataset('OpenLLM-France/wikimedia', 'cpt_wikipedia', subset='fr')
#
# NameError: name 'loadDataset' is not defined

# %%
#@title Gutenberg data
datasets['gutenberg'] = loadDataset('OpenLLM-France/Lucie-Training-Dataset', 'cpt_ebook', subset='Gutenberg-fr')
# Out:
# README.md: 0.00B [00:00, ?B/s]
# Resolving data files:   0%|          | 0/9491 [00:00<?, ?it/s]
# data/v1.1/natural/fr/Gutenberg/Gutenberg(…):   0%|          | 0.00/246M [00:00<?, ?B/s]
# data/v1.1/natural/fr/Gutenberg/Gutenberg(…):   0%|          | 0.00/247M [00:00<?, ?B/s]
# data/v1.1/natural/fr/Gutenberg/Gutenberg(…):   0%|          | 0.00/240M [00:00<?, ?B/s]
# data/v1.1/natural/fr/Gutenberg/Gutenberg(…):   0%|          | 0.00/158M [00:00<?, ?B/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# Map:   0%|          | 0/3449 [00:00<?, ? examples/s]

# %%
#@title Dump datasets
dumpDatasets(datasets)
# Out:
# ========================= GUTENBERG =========================
# ########## TEXT
# ('Book\n'
#  '### Title: Œuvres complètes de Alfred de Musset — Tome 4\n'
#  '\n'
#  '### Author: Musset, Alfred de\n'
#  '\n'
#  '### Content:\n'
#  'OEUVRES COMPLÈTES\n'
#  '\n'
#  '                                DE\n'
#  '\n'
#  '                         ALFRED DE MUSSET\n'
#  '\n'
#  "ÉDITION ORNÉE DE 28 GRAVURES D'APRÈS LES DESSINS DE BIDA D'UN PORTRAIT\n"
#  "GRAVÉ PAR FLAMENG; D'APRÈS L'ORIGINAL DE LANDELLE ET ACCOMPAGNÉE D'UNE\n"
#  'NOTICE SUR ALFRED DE MUSSET PAR SON FRÈRE\n'
#  '\n'
#  '                          TOME QUATRIÈME\n'
#  '\n'
#  '                             COMÉDIES\n'
#  '                                II\n'
#  '\n'
#  'PARIS EDITION CHARPENTIER L. HÉBERT, LIBRAIRE 7, RUE PERRONET, 7\n'
#  '\n'
#  '1888\n'
#  '\n'
#  '       *       *       *       *       *\n'
#  '\n'
#  '                            LORENZACCIO\n'
#  '\n'
#  '                        DRAME EN CINQ ACTES\n'
#  '\n'
#  '                               1834\n'
#  '\n'
#  'PERSONNAGES.\n'
#  '\n'
#  '    ALEXANDRE DE MÉDICIS, duc de Florence.\n'
#  '\n'
#  '    LORENZO DE MÉDICIS (LORENZACCIO),\n'
#  '    COME DE MÉDICIS,                  ses cousins\n'
#  '\n'
#  '    LE CARDINAL CIBO.\n'
#  '\n'
#  '    LE MARQUIS DE CIBO, son frère.\n'
#  '\n'
#  '    SIRE MAURICE, chancelier des Huit.\n'
#  '\n'
#  '    LE CARDINAL BACCIO VALORI, commissaire apostolique.\n'
#  '\n'
#  '    JULIEN SALVIATI.\n'
#  '\n'
#  '    PHILIPPE STROZZI.\n'
#  '    PIERRE STROZZI,\n'
#  '    THOMAS STROZZI,\n'
#  '    LÉON STROZZI, prieur de Capoue, ses fils.\n'
#  '\n'
#  '    ROBERTO CORSINI, provéditeur de la forteresse.\n'
#  '\n'
#  '    PALLA RUCCELLAI,\n'
#  '    ALAMANNO SALVIATI,\n'
#  '    FRANÇOIS PAZZI, seigneurs républicains.\n'
#  '\n'
#  '    BINDO ALTOVITI, oncle de Lorenzo.\n'
#  '\n'
#  '    VENTURI, bourgeois.\n'
#  '\n'
#  '    TEBALDEO, peintre.\n'
#  '\n'
#  '    SCORONCONCOLO, spadassin.\n'
#  '\n'
#  '    LES HUIT.\n'
#  '\n'
#  '    GIOMO LE HONGROIS, écuyer du duc.\n'
#  '\n'
#  '    MAFFIO, bourgeois.\n'
#  '\n'
#  '    MARIE SODERINI, mère de Lorenzo.\n'
#  '\n'
#  '    CATHERINE GINORI, sa tante.\n'
#  '\n'
#  '    LA MARQUISE DE CIBO.\n'
#  '\n'
#  '    LOUISE STROZZI.\n'
#  '\n'
#  '    DEUX DAMES DE LA COUR ET UN OFFICIER ALLEMAND.\n'
#  '\n'
#  '    UN ORFÈVRE, UN MARCHAND, DEUX PRÉCEPTEURS ET DEUX ENFANTS,\n'
#  '    PAGES, SOLDATS, MOINES, COURTISANS, BANNIS, ÉCOLIERS,\n'
#  '    DOMESTIQUES, BOURGEOIS, ETC., ETC.\n'
#  '\n'
#  '_La scène est à Florence._\n'
#  '\n'
#  '[Illustration: Dessin de Bida. Gravé par Levasseur\n'
#  '\n'
#  'LORENZACCIO.\n'
#  '\n'
#  'LE DUC.\n'
#  '\n'
#  "C'est toi, Renzo?\n"
#  '\n'
#  'LORENZO.\n'
#  '\n'
#  "Seigneur, n'en doutez pas.\n"
#  '\n'
#  '_Acte IV, Scène XI_]\n'
#  '\n'
#  'ACTE PREMIER\n'
#  '\n'
#  'SCÈNE PREMIÈRE\n'
#  '\n'
#  '_Un jardin.--Clair de lune.--Un pavillon dans le fond, un autre sur le\n'
#  'devant._\n'
#  '\n'
#  '_Entrent_ LE DUC ET LORENZO, _couverts de leurs manteaux_; GIOMO, _une\n'
#  'lanterne à la main_.\n'
#  '\n'
#  'LE DUC.\n'
#  '\n'
#  "Qu'elle se fasse attendre encore un quart d'heure, et je m'en vais. Il\n"
#  'fait un froid de tous les diables.\n'
#  '\n'
#  'LORENZO.\n'
#  '\n'
#  'Patience, Altesse, patience.\n'
#  '\n'
#  'LE DUC.\n'
#  '\n'
#  'Elle devait sortir de chez sa mère à minuit; il est minuit, et elle ne\n'
#  'vient pourtant pas.\n'
#  '\n'
#  'LORENZO.\n'
#  '\n'
#  'Si elle ne vient pas, dites que je suis un sot, et que la vieille mère\n'
#  'est une honnête femme.\n'
#  '\n'
#  'LE DUC.\n'
#  '\n'
#  "Entrailles du pape! avec tout cela je suis volé d'un millier de\n"
#  'ducats.\n'
#  '\n'
#  'LORENZO.\n'
#  '\n'
#  "Nous n'avons avancé que moitié. Je réponds de la petite. Deux grands\n"
#  'yeux languissants, cela ne trompe pas. Quoi de plus curieux pour\n'
#  'le connaisseur que la débauche à la mamelle? Voir dans un enfant\n'
#  'de quinze ans la rouée à venir; étudier, ensemencer, infiltrer\n'
#  "paternellement le filon mystérieux du vice dans un conseil d'ami, dans\n"
#  'une caresse au menton;--tout dire et ne rien dire, selon le caractère\n'
#  "des parents;--habituer doucement l'imagination qui se développe\n"
#  "à donner des corps à ses fantômes, à toucher ce qui l'effraye, à\n"
#  "mépriser ce qui la protège! Cela va plus vite qu'on ne pense; le vrai\n"
#  'mérite est de frapper juste. Et quel trésor que celle-ci! tout ce qui\n'
#  'peut faire passer une nuit délicieuse à Votre Altesse! Tant de pudeur!\n'
#  'Une jeune chatte qui veut bien des confitures, mais qui ne veut pas se\n'
#  'salir la patte. Proprette comme une Flamande! La médiocrité bourgeoise\n'
#  "en personne. D'ailleurs, fille de bonnes gens, à qui leur peu de\n"
#  "fortune n'a pas permis une éducation solide; point de fond dans les\n"
#  "principes, rien qu'un léger vernis; mais quel flot violent d'un fleuve\n"
#  'magnifique sous cette couche de glace fragile qui craque à chaque pas!\n'
#  "Jamais arbuste en fleur n'a promis de fruits plus rares, jamais\n"
#  "je n'ai humé dans une atmosphère enfantine plus exquise odeur de\n"
#  'courtisanerie.\n'
#  '\n'
#  'LE DUC.\n'
#  '\n'
#  "Sacrebleu! je ne vois pas le signal. Il faut pourtant que j'aille au\n"
#  "bal chez Nasi: c'est aujourd'hui qu'il marie sa fille.\n"
#  '\n'
#  'GIOMO.\n'
#  '\n'
#  "Allons au pavillon, monseigneur; puisqu'il ne s'agit que d'emporter\n"
#  'une fille qui est à moitié payée, nous pouvons bien taper aux\n'
#  'carreaux.\n'
#  '\n'
#  'LE DUC.\n'
#  '\n'
#  'Viens par ici; le Hongrois a raison.\n'
#  '\n'
#  "_Ils s'éloignent.--Entre Maffio._\n"
#  '\n'
#  'MAFFIO.\n'
#  '\n'
#  'Il me semblait dans mon rêve voir ma soeur traverser notre jardin,\n'
#  'tenant une lanterne sourde, et couverte de pierreries. Je me suis\n'
#  "éveillé en sursaut. Dieu sait que ce n'est qu'une illusion, mais une\n"
#  "illusion trop forte pour que le sommeil ne s'enfuie pas devant elle.\n"
#  'Grâce au ciel, les fenêtres du pavillon où couche la petite sont\n'
#  "fermées comme de coutume; j'aperçois faiblement la lumière de sa\n"
#  'lampe entre les feuilles de notre vieux figuier. Maintenant mes folles\n'
#  'terreurs se dissipent; les battements précipités de mon coeur font\n'
#  'place à une douce tranquillité. Insensé! mes yeux se remplissent\n'
#  'de larmes, comme si ma pauvre soeur avait couru un véritable\n'
#  "danger.--Qu'entends-je? Qui remue là entre les branches?\n"
#  '\n'
#  "_La soeur de Maffio passe dans l'éloignement._\n"
#  '\n'
#  "Suis-je éveillé? c'est le fantôme de ma soeur. Il tient une lanterne\n"
#  'sourde, et un collier brillant étincelle, sur sa poitrine aux rayons\n'
#  'de la lune. Gabrielle! Gabrielle! où vas-tu?\n'
#  '\n'
#  '_Rentrent Giomo et le duc._\n'
#  '\n'
#  'GIOMO.\n'
#  '\n'
#  'Ce sera le bonhomme de frère pris de somnambulisme.--Lorenzo\n'
#  'conduira votre belle au palais par la petite porte; et quant à nous,\n'
#  "qu'avons-nous à craindre?\n"
#  '\n'
#  'MAFFIO.\n'
#  '\n'
#  'Qui êtes-vous? Holà! arrêtez!\n'
#  '\n'
#  '_Il tire son épée._\n'
#  '\n'
#  'GIOMO.\n'
#  '\n'
#  'Honnête rustre, nous sommes tes amis.\n'
#  '\n'
#  'MAFFIO.\n'
#  '\n'
#  'Où est ma soeur? que cherchez-vous ici?\n'
#  '\n'
#  'GIOMO.\n'
#  '\n'
#  'Ta soeur est dénichée, brave canaille. Ouvre la grille de ton\n'
#  'jardin.\n'
#  '\n'
#  'MAFFIO.\n'
#  '\n'
#  'Tire ton épée et défends-toi, assassin que tu es!\n'
#  '\n'
#  'GIOMO _saute sur lui et le désarme_.\n'
#  '\n'
#  'Halte-là! maître sot, pas si vite!\n'
#  '\n'
#  'MAFFIO.\n'
#  '\n'
#  "O honte! ô excès de misère! S'il y a des lois à Florence, si quelque\n"
#  "justice vit encore sur la terre, par ce qu'il y a de vrai et de sacré\n"
#  'au monde, je me jetterai aux pieds du duc, et il vous fera pendre tous\n'
#  'les deux.\n'
#  '\n'
#  'GIOMO.\n'
#  '\n'
#  'Aux pieds du duc?\n'
#  '\n'
#  'MAFFIO.\n'
#  '\n'
#  'Oui, oui, je sais que les gredins de votre espèce égorgent impunément\n'
#  'les familles. Mais que je meure, entendez-vous, je ne mourrai pas\n'
#  "silencieux comme tant d'autres. Si le duc ne sait pas que sa ville\n"
#  "est une forêt pleine de bandits, pleine d'empoisonneurs et de filles\n"
#  'déshonorées, en voilà un qui le lui dira. Ah! massacre! ah! fer et\n'
#  "sang! j'obtiendrai justice de vous!\n"
#  '\n'
#  "GIOMO, _l'épée à la main_.\n"
#  '\n'
#  'Faut-il frapper, Altesse?\n'
#  '\n'
#  'LE DUC.\n'
#  '\n'
#  'Allons donc! frapper ce pauvre homme! Va te recoucher, mon ami: nous\n'
#  "t'enverrons demain quelques ducats.\n"
#  '\n'
#  '_Il sort._\n'
#  '\n'
#  'MAFFIO.\n'
#  '\n'
#  "C'est Alexandre de Médicis!\n"
#  '\n'
#  'GIOMO.\n'
#  '\n'
#  'Lui-même, mon brave rustre. Ne te vante pas de sa visite si tu tiens à\n'
#  'tes oreilles.\n'
#  '\n'
#  '_Il sort._\n'
#  '\n'
#  'SCÈNE II\n'
#  '\n'
#  "_Une rue.--Le point du jour.--Plusieurs masques sortent d'une maison\n"
#  'illuminée._\n'
#  '\n'
#  'UN MARCHAND DE SOIERIES ET UN ORFÈVRE _ouvrent leur boutique_.\n'
#  '\n'
#  'LE MARCHAND DE SOIERIES.\n'
#  '\n'
#  'Hé! hé! père Mondella, voilà bien du vent pour mes étoffes.\n'
#  '\n'
#  '_Il étale ses pièces de soie._\n'
#  '\n'
#  "L'ORFÈVRE, _bâillant_.\n"
#  '\n'
#  "C'est à se casser la tête. Au diable leur noce! je n'ai pas fermé\n"
#  "l'oeil de la nuit.\n"
#  '\n'
#  'LE MARCHAND.\n'
#  '\n'
#  "Ni ma femme non plus, voisin; la chère âme s'est tournée et retournée\n"
#  "comme une anguille. Ah! dame! quand on est jeune, en ne s'endort pas\n"
#  'au bruit des violons.\n'
#  '\n'
#  "L'ORFÈVRE.\n"
#  '\n'
#  "Jeune! jeune! cela vous plaît à dire. On n'est pas jeune avec une\n"
#  'barbe comme celle-là; et cependant. Dieu sait si leur damnée de\n'
#  'musique me donne envie de danser!\n'
#  '\n'
#  '_Deux écoliers passent._\n'
#  '\n'
#  'PREMIER ÉCOLIER.\n'
#  '\n'
#  "Rien n'est plus amusant. On se glisse contre la porte au milieu des\n"
#  'soldats, et on les voit descendre avec leurs habits de toutes les\n'
#  'couleurs. Tiens! voilà la maison des Nasi.\n'
#  '\n'
#  '_Il souffle dans ses doigts._\n'
#  '\n'
#  'Mon portefeuille me glace les mains.\n'
#  '\n'
#  'DEUXIÈME ÉCOLIER.\n'
#  '\n'
#  'Et on nous laissera approcher?\n'
#  '\n'
#  'PREMIER ÉCOLIER.\n'
#  '\n'
#  "En vertu de quoi est-ce qu'on nous en empêcherait? Nous sommes\n"
#  'citoyens de Florence. Regarde tout ce monde autour de la porte; en\n'
#  'voilà des chevaux, des pages et des livrées! Tout cela va et vient, il\n'
#  "n'y a qu'à s'y connaître un peu; je suis capable de nommer toutes les\n"
#  "personnes d'importance; on observe bien tous les costumes, et le soir\n"
#  "on dit à l'atelier: J'ai une terrible envie de dormir, j'ai passé la\n"
#  'nuit au bal chez le prince Aldobrandini, chez le comte Salviati; le\n'
#  'prince était habillé de telle ou telle façon, la princesse de telle\n'
#  'autre, et on ne ment pas. Viens, prends ma cape par derrière.\n'
#  '\n'
#  '_Ils se placent contre la porte de la maison._\n'
#  '\n'
#  "L'ORFÈVRE.\n"
#  '\n'
#  "Entendez-vous les petits badauds? Je voudrais qu'un de mes apprentis\n"
#  'fît un pareil métier!\n'
#  '\n'
#  'LE MARCHAND.\n'
#  '\n'
#  "Bon, bon! père Mondella, où le plaisir ne coûte rien, la jeunesse n'a\n"
#  'rien à perdre. Tous ces grands yeux étonnés de ces petits polissons\n'
#  "me réjouissent le coeur.--Voilà comme j'étais, humant l'air\n"
#  'et cherchant les nouvelles. Il paraît que la Nasi est une belle\n'
#  "gaillarde, et que le Martelli est un heureux garçon. C'est une\n"
#  'famille bien florentine, celle-là! Quelle tournure ont tous ces grands\n'
#  "seigneurs! J'avoue que ces fêtes-là me font plaisir, à moi. On est\n"
#  'dans son lit bien tranquille, avec un coin de ses rideaux retroussé;\n'
#  'on regarde de temps en temps les lumières qui vont et viennent dans\n'
#  'le palais; on attrape un petit air de danse sans rien payer, et on se\n'
#  'dit: Hé! hé! ce sont mes étoffes qui dansent, mes belles étoffes du\n'
#  'bon Dieu, sur le cher corps de tous ces braves et loyaux seigneurs.\n'
#  '\n'
#  "L'ORFÈVRE.\n"
#  '\n'
#  "Il en danse plus d'une qui n'est pas payée, voisin; ce sont celles-là\n"
#  "qu'on arrose de vin et qu'on frotte sur les murailles avec le moins\n"
#  "de regret. Que les grands seigneurs s'amusent, c'est tout simple,--ils\n"
#  'sont nés pour cela; mais il y a des amusements de plusieurs sortes,\n'
#  'entendez-vous?\n'
#  '\n'
#  'LE MARCHAND.\n'
#  '\n'
#  "Oui, oui, comme la danse, le cheval, le jeu de paume et tant d'autres.\n"
#  "Qu'entendez-vous vous-même, père Mondella?\n"
#  '\n'
#  "L'ORFÈVRE.\n"
#  '\n'
#  "Cela suffit;--je me comprends.--C'est-à-dire que les murailles de tous\n"
#  "ces palais-là n'ont jamais mieux prouvé leur solidité. Il leur fallait\n"
#  "moins de force pour défendre les aïeux de l'eau du ciel, qu'il ne leur\n"
#  'en faut pour soutenir les fils quand ils ont trop pris de leur vin.\n'
#  '\n'
#  'LE MARCHAND.\n'
#  '\n'
#  'Un verre de vin est de bon conseil, père Mondella. Entrez donc dans ma\n'
#  'boutique que je vous montre une pièce de velours.\n'
#  '\n'
#  "L'ORFÈVRE.\n"
#  '\n'
#  'Oui, de bon conseil et de bonne mine, voisin; un bon verre de vin\n'
#  "vieux a une bonne mine au bout d'un bras qui a sué pour le gagner; on\n"
#  "le soulève gaiement d'un petit coup, et il s'en va donner du courage\n"
#  "au coeur de l'honnête homme qui travaille pour sa famille. Mais ce\n"
#  'sont des tonneaux sans vergogne, que tous ces godelureaux de la cour.\n'
#  "A qui fait-on plaisir en s'abrutissant jusqu'à la bête féroce? A\n"
#  'personne, pas même à soi, et à Dieu encore moins.\n'
#  '\n'
#  'LE MARCHAND.\n'
#  '\n'
#  "Le carnaval a été rude, il faut l'avouer; et leur maudit ballon m'a\n"
#  'gâté de la marchandise pour une cinquantaine de florins[A]. Dieu\n'
#  "merci! les Strozzi l'ont payé.\n"
#  '\n'
#  "[Note A: C'était l'usage au carnaval de traîner dans les rues\n"
#  'un énorme ballon qui renversait les passants et les devantures des\n'
#  'boutiques. Pierre Strozzi avait été arrêté pour ce fait. (_Note de\n'
#  "l'auteur._)]\n"
#  '\n'
#  "L'ORFÈVRE.\n"
#  '\n'
#  'Les Strozzi! Que le ciel confonde ceux qui ont osé porter la main sur\n'
#  "leur neveu! Le plus brave homme de Florence, c'est Philippe Strozzi.\n"
#  '\n'
#  'LE MARCHAND.\n'
#  '\n'
#  "Cela n'empêche pas Pierre Strozzi d'avoir traîné son maudit ballon sur\n"
#  "ma boutique, et de m'avoir fait trois grandes taches dans une aune\n"
#  'de velours brodé. A propos, père Mondella, nous verrons-nous à\n'
#  'Montolivet?\n'
#  '\n'
#  "L'ORFÈVRE.\n"
#  '\n'
#  "Ce n'est pas mon métier de suivre les foires; j'irai cependant à\n"
#  "Montolivet par piété. C'est un saint pèlerinage, voisin, et qui remet\n"
#  'tous les péchés.\n'
#  '\n'
#  'LE MARCHAND.\n'
#  '\n'
#  'Et qui est tout à fait vénérable, voisin, et qui fait gagner les\n'
#  "marchands plus que tous les autres jours de l'année. C'est plaisir de\n"
#  'voir ces bonnes dames, sortant de la messe, manier, examiner toutes\n'
#  'les étoffes. Que Dieu conserve Son Altesse! La cour est une belle\n'
#  'chose.\n'
#  '\n'
#  "L'ORFÈVRE.\n"
#  '\n'
#  'La cour! le peuple la porte sur le dos, voyez-vous. Florence était\n'
#  "encore (il n'y a pas longtemps de cela) une bonne maison bien\n"
#  'bâtie; tous ces grands palais, qui sont les logements de nos grandes\n'
#  "familles, en étaient les colonnes. Il n'y en avait pas une, de toutes\n"
#  "ces colonnes, qui dépassât les autres d'un pouce; elles soutenaient à\n"
#  'elles toutes une vieille voûte bien cimentée, et nous nous promenions\n'
#  "là-dessous sans crainte d'une pierre sur la tête. Mais il y a de par\n"
#  "le monde deux architectes malavisés qui ont gâté l'affaire; je vous le\n"
#  "dis en confidence, c'est le pape et l'empereur Charles. L'empereur a\n"
#  'commencé par entrer par une assez bonne brèche dans la susdite maison.\n'
#  'Après quoi, ils ont jugé à propos de prendre une des colonnes dont je\n'
#  "vous parle, à savoir celle de la famille des Médicis, et d'en faire un\n"
#  'clocher, lequel clocher a poussé comme un champignon de malheur dans\n'
#  "l'espace d'une nuit. Et puis, savez-vous, voisin? comme l'édifice\n"
#  "branlait au vent, attendu qu'il avait la tête trop lourde et une jambe\n"
#  'de moins, on a remplacé le pilier devenu clocher par un gros pâté\n'
#  'informe fait de boue et de crachat, et on a appelé cela la citadelle:\n'
#  'les Allemands se sont installés dans ce maudit trou comme des rats\n'
#  'dans un fromage, et il est bon de savoir que, tout en jouant aux dés\n'
#  "et en buvant leur vin aigrelet, ils ont l'oeil sur nous autres. Les\n"
#  'familles florentines ont beau crier, le peuple et les marchands ont\n'
#  'beau dire, les Médicis gouvernent au moyen de leur garnison; ils nous\n'
#  'dévorent comme une excroissance vénéneuse dévore un estomac malade;\n'
#  "c'est en vertu des hallebardes qui se promènent sur la plate-forme,\n"
#  "qu'un bâtard, une moitié de Médicis, un butor que le ciel avait fait\n"
#  'pour être garçon boucher ou valet de charrue, couche dans le lit\n'
#  'de nos filles, boit nos bouteilles, casse nos vitres; et encore le\n'
#  'paye-t-on pour cela.\n'
#  '\n'
#  'LE MARCHAND.\n'
#  '\n'
#  "Peste! peste! comme vous y allez! vous avez l'air de savoir tout cela\n"
#  'par coeur; il ne ferait pas bon dire cela dans toutes les oreilles,\n'
#  'voisin Mondella.\n'
#  '\n'
#  "L'ORFÈVRE.\n"
#  '\n'
#  "Et quand on me bannirait comme tant d'autres! On vit à Rome aussi bien\n"
#  "qu'ici. Que le diable emporte la noce, ceux qui y dansent et ceux qui\n"
#  'la font!\n'
#  '\n'
#  '_Il rentre. Le marchand se mêle aux curieux.--Passe un bourgeois, avec\n'
#  'sa femme._\n'
#  '\n'
#  'LA FEMME.\n'
#  '\n'
#  "Guillaume Martelli est un bel homme et riche. C'est un bonheur pour\n"
#  "Nicolo Nasi d'avoir un gendre comme celui-là. Tiens! le bal dure\n"
#  'encore.--Regarde donc toutes ces lumières.\n'
#  '\n'
#  'LE BOURGEOIS.\n'
#  '\n'
#  'Et nous, notre fille, quand la marierons-nous?\n'
#  '\n'
#  'LA FEMME.\n'
#  '\n'
#  "Comme tout est illuminé! Danser encore à l'heure qu'il est, c'est là\n"
#  'une jolie fête!--On dit que le duc y est.\n'
#  '\n'
#  'LE BOURGEOIS.\n'
#  '\n'
#  "Faire du jour la nuit et de la nuit le jour, c'est un moyen commode\n"
#  'de ne pas voir les honnêtes gens. Une belle invention, ma foi, que des\n'
#  "hallebardes à la porte d'une noce! Que le bon Dieu protège la ville!\n"
#  "Il en sort tous les jours de nouveaux, de ces chiens d'Allemands, de\n"
#  'leur damnée forteresse.\n'
#  '\n'
#  'LA FEMME.\n'
#  '\n'
#  'Regarde donc le joli masque. Ah! la belle robe! Hélas! tout cela coûte\n'
#  'très cher, et nous sommes bien pauvres à la maison.\n'
#  '\n'
#  '_Ils sortent._\n'
#  '\n'
#  'UN SOLDAT, _au marchand_.\n'
#  '\n'
#  'Gare, canaille! laisse passer les chevaux.\n'
#  '\n'
#  'LE MARCHAND.\n'
#  '\n'
#  'Canaille toi-même, Allemand du diable!\n'
#  '\n'
#  '_Le soldat le frappe de sa pique._\n'
#  '\n'
#  'LE MARCHAND, _se retirant_.\n'
#  '\n'
#  'Voilà comme on suit la capitulation! Ces gredins-là maltraitent les\n'
#  'citoyens.\n'
#  '\n'
#  '_Il rentre chez lui._\n'
#  '\n'
#  "L'ÉCOLIER, _à son camarade._\n"
#  '\n'
#  "Vois-tu celui-là qui ôte son masque? C'est Palla Ruccellai. Un fier\n"
#  "luron! Ce petit-là, à côté de lui, c'est Thomas Strozzi, Masaccio,\n"
#  'comme on dit.\n'
#  '\n'
#  'UN PAGE, _criant._\n'
#  '\n'
#  'Le cheval de son Altesse!\n'
#  '\n'
#  'LE SECOND ÉCOLIER.\n'
#  '\n'
#  'Allons-nous-en, voilà le duc qui sort.\n'
#  '\n'
#  'LE PREMIER ÉCOLIER.\n'
#  '\n'
#  "Crois-tu pas qu'il va te manger?\n"
#  '\n'
#  "_La foule s'augmente à la porte._\n"
#  '\n'
#  "L'ÉCOLIER.\n"
#  '\n'
#  "Celui-là, c'est Nicolini; celui-là, c'est le provéditeur.\n"
#  '\n'
#  '_Le duc sort, vêtu en religieuse, avec Julien Salviati, habillé de\n'
#  'même, tous deux masqués._\n'
#  '\n'
#  'LE DUC, _montant à cheval_.\n'
#  '\n'
#  'Viens-tu, Julien?\n'
#  '\n'
#  'SALVIATI.\n'
#  '\n'
#  'Non, Altesse, pas encore.\n'
#  '\n'
#  "_Il lui parle à l'oreille._\n"
#  '\n'
#  'LE DUC.\n'
#  '\n'
#  'Bien, bien, ferme!\n'
#  '\n'
#  'SALVIATI.\n'
#  '\n'
#  'Elle est belle comme un démon.--Laissez-moi faire; si je peux me\n'
#  'débarrasser de ma femme...\n'
#  '\n'
#  '_Il rentre dans le bal._\n'
#  '\n'
#  'LE DUC.\n'
#  '\n'
#  'Tu es gris, Salviati; le diable m')

# %%
#@title Merge datasets
dataset = mergeDatasets(datasets)
# Out:
# ========================= EBOOKS =========================
# ########## TEXT
# ('Epub Book\n'
#  '### Filename: crime du golf, Le - Agatha Christie.epub\n'
#  '\n'
#  '### Title: Le crime du golf\n'
#  '\n'
#  '### Author: Agatha Christie\n'
#  '\n'
#  '### Subject: Policier\n'
#  '\n'
#  '### Part: Christie,Agatha-Le crime du '
#  'golf(1923).French.ebook.AlexandriZ_split_024\n'
#  '\n'
#  '### Content:\n'
#  '24  Sauvez\\-le !\n'
#  '================\n'
#  '\n'
#  'Nous revînmes en France par le bateau\n'
#  'du soir, pour nous trouver le lendemain matin à Saint\\-Omer, où l’on avait\n'
#  'transféré Jack Renauld. Poirot voulut aussitôt rendre visite à M. Hautet. '
#  'Comme\n'
#  'il ne semblait voir aucune objection à ma présence, je l’accompagnai.\n'
#  '\n'
#  'Après diverses formalités, nous\n'
#  'fûmes introduits dans le bureau du magistrat, qui nous accueillit avec\n'
#  'cordialité.\n'
#  '\n'
#  '— Je m’étais laissé dire que\n'
#  'vous étiez retourné en Angleterre, monsieur Poirot. Je me réjouis de '
#  'constater\n'
#  'qu’il n’en est rien.\n'
#  '\n'
#  '— J’y suis allé, en effet, mais\n'
#  'pour une simple visite éclair. Une piste d’intérêt secondaire, qui méritait\n'
#  'malgré tout d’être examinée de près.\n'
#  '\n'
#  '— Et vous êtes satisfait ?\n'
#  '\n'
#  'Poirot haussa les épaules. M. Hautet\n'
#  'hocha la tête avec un so')

# %% [markdown]
# ## Training
# Now let's use Unsloth's `UnslothTrainer`! More docs here: [TRL SFT docs](https://huggingface.co/docs/trl/sft_trainer).
# Also set `embedding_learning_rate` to be a learning rate at least 2x or 10x smaller than `learning_rate` to make continual pretraining work!

# %% [markdown]
# ### Setup Trainer

# %%
from transformers import TrainingArguments
from unsloth import UnslothTrainer, UnslothTrainingArguments

trainer = UnslothTrainer(
    model = model,
    tokenizer = tokenizer,
    train_dataset = dataset,
    dataset_text_field = "text",
    max_seq_length = max_seq_length,
    dataset_num_proc = dataset_processors,

    args = UnslothTrainingArguments(
        per_device_train_batch_size = 2,
        gradient_accumulation_steps = 8,

        # Use warmup_ratio and num_train_epochs for longer runs!
        max_steps = 60 if debug else -1, # None for full run
        num_train_epochs = 0 if debug else 1,
        warmup_ratio = 0.1,

        # Select a 2 to 10x smaller learning rate for the embedding matrices!
        learning_rate = 5e-5,
        embedding_learning_rate = 1e-5,

        logging_steps = 1,
        optim = "adamw_8bit",
        weight_decay = 0.01,
        lr_scheduler_type = "linear",
        seed = 3407,
        output_dir = "outputs",
        report_to = "none", # Use this for WandB etc
    ),
)
# Out:
# Unsloth: Tokenizing ["text"] (num_proc=6):   0%|          | 0/2179 [00:00<?, ? examples/s]

# %% [markdown]
# ### Training Execution
# Execute the training process with the configured trainer and monitor the training progress.

# %%
gpu_stats = torch.cuda.get_device_properties(0)
start_gpu_memory = round(torch.cuda.max_memory_reserved() / 1024 / 1024 / 1024, 3)
max_memory = round(gpu_stats.total_memory / 1024 / 1024 / 1024, 3)
print(f"GPU = {gpu_stats.name}. Max memory = {max_memory} GB.")
print(f"{start_gpu_memory} GB of memory reserved.")
# Out:
# GPU = Tesla T4. Max memory = 14.741 GB.
# 8.863 GB of memory reserved.

# %%
trainer_stats = trainer.train()
# Out:
# ==((====))==  Unsloth - 2x faster free finetuning | Num GPUs used = 1
#    \\   /|    Num examples = 2,179 | Num Epochs = 1 | Total steps = 60
# O^O/ \_/ \    Batch size per device = 2 | Gradient accumulation steps = 8
# \        /    Data Parallel GPUs = 1 | Total batch size (2 x 8 x 1) = 16
#  "-____-"     Trainable parameters = 555,565,056 of 3,630,663,680 (15.30% trained)
# Unsloth: Will smartly offload gradients to save VRAM!
#     <div>
#
#       <progress value='2' max='60' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [ 2/60 : < :, Epoch 0.01/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
# ---------------------------------------------------------------------------
# OutOfMemoryError                          Traceback (most recent call last)
# /tmp/ipython-input-773422404.py in <cell line: 0>()
# ----> 1 trainer_stats = trainer.train()
#
# /usr/local/lib/python3.12/dist-packages/transformers/trainer.py in train(self, resume_from_checkpoint, trial, ignore_keys_for_eval, **kwargs)
#    2236                 hf_hub_utils.enable_progress_bars()
#    2237         else:
# -> 2238             return inner_training_loop(
#    2239                 args=args,
#    2240                 resume_from_checkpoint=resume_from_checkpoint,
#
# /usr/local/lib/python3.12/dist-packages/unsloth_zoo/compiler.py in _fast_inner_training_loop(self, batch_size, args, resume_from_checkpoint, trial, ignore_keys_for_eval)
#
# /content/unsloth_compiled_cache/UnslothSFTTrainer.py in training_step(self, *args, **kwargs)
#     971     def training_step(self, *args, **kwargs):
#     972         with self.maybe_activation_offload_context:
# --> 973             return super().training_step(*args, **kwargs)
#     974
#     975     def log(self, logs: dict[str, float], start_time: Optional[float] = None) -> None:
#
# /usr/local/lib/python3.12/dist-packages/unsloth/models/_utils.py in _unsloth_training_step(self, model, inputs, num_items_in_batch)
#
# /content/unsloth_compiled_cache/UnslothSFTTrainer.py in compute_loss(self, model, inputs, return_outputs, num_items_in_batch)
#     960
#     961     def compute_loss(self, model, inputs, return_outputs = False, num_items_in_batch = None):
# --> 962         outputs = super().compute_loss(
#     963             model,
#     964             inputs,
#
# /usr/local/lib/python3.12/dist-packages/unsloth/models/_utils.py in _unsloth_pre_compute_loss(self, model, inputs, *args, **kwargs)
#    1312         )
#    1313     pass
# -> 1314     outputs = self._old_compute_loss(model, inputs, *args, **kwargs)
#    1315     return outputs
#    1316 pass
#
# /usr/local/lib/python3.12/dist-packages/transformers/trainer.py in compute_loss(self, model, inputs, return_outputs, num_items_in_batch)
#    3882                 kwargs["num_items_in_batch"] = num_items_in_batch
#    3883             inputs = {**inputs, **kwargs}
# -> 3884         outputs = model(**inputs)
#    3885         # Save past state if it exists
#    3886         # TODO: this needs to be fixed and made cleaner later.
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1771             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772         else:
# -> 1773             return self._call_impl(*args, **kwargs)
#    1774
#    1775     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1782                 or _global_backward_pre_hooks or _global_backward_hooks
#    1783                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784             return forward_call(*args, **kwargs)
#    1785
#    1786         result = None
#
# /usr/local/lib/python3.12/dist-packages/accelerate/utils/operations.py in forward(*args, **kwargs)
#     816
#     817     def forward(*args, **kwargs):
# --> 818         return model_forward(*args, **kwargs)
#     819
#     820     # To act like a decorator so that it can be popped when doing `extract_model_from_parallel`
#
# /usr/local/lib/python3.12/dist-packages/accelerate/utils/operations.py in __call__(self, *args, **kwargs)
#     804
#     805     def __call__(self, *args, **kwargs):
# --> 806         return convert_to_fp32(self.model_forward(*args, **kwargs))
#     807
#     808     def __getstate__(self):
#
# /usr/local/lib/python3.12/dist-packages/torch/amp/autocast_mode.py in decorate_autocast(*args, **kwargs)
#      42     def decorate_autocast(*args, **kwargs):
#      43         with autocast_instance:
# ---> 44             return func(*args, **kwargs)
#      45
#      46     decorate_autocast.__script_unsupported = "@autocast() decorator is not supported in script mode"  # type: ignore[attr-defined]
#
# /usr/local/lib/python3.12/dist-packages/peft/peft_model.py in forward(self, input_ids, attention_mask, inputs_embeds, labels, output_attentions, output_hidden_states, return_dict, task_ids, **kwargs)
#    1848             with self._enable_peft_forward_hooks(**kwargs):
#    1849                 kwargs = {k: v for k, v in kwargs.items() if k not in self.special_peft_forward_args}
# -> 1850                 return self.base_model(
#    1851                     input_ids=input_ids,
#    1852                     attention_mask=attention_mask,
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1771             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772         else:
# -> 1773             return self._call_impl(*args, **kwargs)
#    1774
#    1775     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1782                 or _global_backward_pre_hooks or _global_backward_hooks
#    1783                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784             return forward_call(*args, **kwargs)
#    1785
#    1786         result = None
#
# /usr/local/lib/python3.12/dist-packages/peft/tuners/tuners_utils.py in forward(self, *args, **kwargs)
#     220
#     221     def forward(self, *args: Any, **kwargs: Any):
# --> 222         return self.model.forward(*args, **kwargs)
#     223
#     224     def _pre_injection_hook(self, model: nn.Module, config: PeftConfig, adapter_name: str) -> None:
#
# /content/unsloth_compiled_cache/unsloth_compiled_module_smollm3.py in forward(self, input_ids, attention_mask, position_ids, past_key_values, inputs_embeds, labels, use_cache, cache_position, logits_to_keep, **kwargs)
#     614         **kwargs: Unpack[TransformersKwargs],
#     615     ) -> CausalLMOutputWithPast:
# --> 616         return SmolLM3ForCausalLM_forward(self, input_ids, attention_mask, position_ids, past_key_values, inputs_embeds, labels, use_cache, cache_position, logits_to_keep, **kwargs)
#
# /usr/local/lib/python3.12/dist-packages/torch/_dynamo/external_utils.py in nonrecursive_disable_wrapper(*args, **kwargs)
#     196     @functools.wraps(fn)
#     197     def nonrecursive_disable_wrapper(*args: _P.args, **kwargs: _P.kwargs) -> _R:
# --> 198         return fn(*args, **kwargs)
#     199
#     200     return nonrecursive_disable_wrapper
#
# /usr/local/lib/python3.12/dist-packages/transformers/utils/generic.py in wrapper(self, *args, **kwargs)
#     957         if return_dict_passed is not None:
#     958             return_dict = return_dict_passed
# --> 959         output = func(self, *args, **kwargs)
#     960         if not return_dict and not isinstance(output, tuple):
#     961             output = output.to_tuple()
#
# /content/unsloth_compiled_cache/unsloth_compiled_module_smollm3.py in SmolLM3ForCausalLM_forward(self, input_ids, attention_mask, position_ids, past_key_values, inputs_embeds, labels, use_cache, cache_position, logits_to_keep, **kwargs)
#     544         torch._dynamo.mark_dynamic(_hidden_states, 1)
#     545         torch._dynamo.mark_dynamic(labels, 1)
# --> 546         loss = unsloth_fused_ce_loss(
#     547             trainer              = None,
#     548             hidden_states        = _hidden_states,
#
# /usr/local/lib/python3.12/dist-packages/unsloth_zoo/fused_losses/cross_entropy_loss.py in unsloth_fused_ce_loss(trainer, hidden_states, lm_head_weight, lm_head_bias, labels, mask, n_items, scaling, target_gb, torch_compile, overwrite, **kwargs)
#     360     scaling = scaler.get_scale() if scaler is not None else scaling
#     361     if hasattr(scaling, "get_scale"): scaling = scaling.get_scale()
# --> 362     return apply_autograd_function(UnslothFusedLoss, dict(
#     363         loss_function = compute_fused_ce_loss,
#     364         hidden_states = hidden_states,
#
# /usr/local/lib/python3.12/dist-packages/unsloth_zoo/fused_losses/cross_entropy_loss.py in apply_autograd_function(autograd, mapping)
#      39 def apply_autograd_function(autograd, mapping):
#      40     parameters, defaults = _get_mapping(autograd)
# ---> 41     return getattr(autograd, "apply")(*(
#      42         mapping.get(old_key, default) \
#      43         for old_key, default in zip(parameters, defaults)
#
# /usr/local/lib/python3.12/dist-packages/torch/autograd/function.py in apply(cls, *args, **kwargs)
#     574             # See NOTE: [functorch vjp and autograd interaction]
#     575             args = _functorch.utils.unwrap_dead_wrappers(args)
# --> 576             return super().apply(*args, **kwargs)  # type: ignore[misc]
#     577
#     578         if not is_setup_ctx_defined:
#
# /usr/local/lib/python3.12/dist-packages/unsloth_zoo/fused_losses/cross_entropy_loss.py in forward(ctx, loss_function, hidden_states, lm_head_weight, lm_head_bias, labels, mask, n_items, scaling, shift_labels, target_gb, torch_compile, overwrite, extra_kwargs)
#     300         for (grad_inputs_j, hidden_states_j, labels_j,) in \
#     301             zip(__grad_inputs, __shift_states, __shift_labels,):
# --> 302             accumulate_chunk(
#     303                 n_chunks = n_chunks,
#     304                 grad_inputs_j = grad_inputs_j,
#
# /usr/local/lib/python3.12/dist-packages/torch/_dynamo/eval_frame.py in compile_wrapper(*args, **kwargs)
#     734
#     735                 try:
# --> 736                     return fn(*args, **kwargs)
#     737                 except Unsupported as e:
#     738                     if config.verbose:
#
# /usr/local/lib/python3.12/dist-packages/unsloth_zoo/fused_losses/cross_entropy_loss.py in accumulate_chunk(n_chunks, grad_inputs_j, grad_lm_head, grad_lm_head_bias, hidden_states_j, lm_head_weight, lm_head_bias, labels_j, divisor, scaling, shift_labels, **kwargs)
#     203         __grad_inputs  = torch.chunk(grad_inputs.view(-1, hd),   n_chunks, dim = 0)
#     204
# --> 205         def accumulate_chunk(
#     206             n_chunks,
#     207             grad_inputs_j,
#
# /usr/local/lib/python3.12/dist-packages/torch/_dynamo/eval_frame.py in _fn(*args, **kwargs)
#     927                 _maybe_set_eval_frame(_callback_from_stance(self.callback))
#     928                 try:
# --> 929                     return fn(*args, **kwargs)
#     930                 finally:
#     931                     set_eval_frame(None)
#
# /usr/local/lib/python3.12/dist-packages/torch/_functorch/aot_autograd.py in forward(*runtime_args)
#    1239         full_args.extend(params_flat)
#    1240         full_args.extend(runtime_args)
# -> 1241         return compiled_fn(full_args)
#    1242
#    1243     # Just for convenience
#
# /usr/local/lib/python3.12/dist-packages/torch/_functorch/_aot_autograd/runtime_wrappers.py in runtime_wrapper(args)
#     382                     torch._C._set_grad_enabled(False)
#     383                 record_runtime_wrapper_prologue_exit(cm)
# --> 384                 all_outs = call_func_at_runtime_with_args(
#     385                     compiled_fn, args, disable_amp=disable_amp, steal_args=True
#     386                 )
#
# /usr/local/lib/python3.12/dist-packages/torch/_functorch/_aot_autograd/utils.py in call_func_at_runtime_with_args(f, args, steal_args, disable_amp)
#     124     with context():
#     125         if getattr(f, "_boxed_call", False):
# --> 126             out = normalize_as_list(f(args))
#     127         else:
#     128             # TODO: Please remove soon
#
# /usr/local/lib/python3.12/dist-packages/torch/_functorch/_aot_autograd/runtime_wrappers.py in inner_fn(args)
#     748                 old_args.clear()
#     749
# --> 750             outs = compiled_fn(args)
#     751
#     752             # Inductor cache DummyModule can return None
#
# /usr/local/lib/python3.12/dist-packages/torch/_functorch/_aot_autograd/runtime_wrappers.py in wrapper(runtime_args)
#     554                 )
#     555                 return out
# --> 556             return compiled_fn(runtime_args)
#     557
#     558         return wrapper
#
# /usr/local/lib/python3.12/dist-packages/torch/_inductor/output_code.py in __call__(self, inputs)
#     582         assert self.current_callable is not None
#     583         try:
# --> 584             return self.current_callable(inputs)
#     585         finally:
#     586             get_runtime_metrics_context().finish()
#
# /usr/local/lib/python3.12/dist-packages/torch/_inductor/utils.py in run(new_inputs)
#    2714             new_inputs, inputs_to_check, mutated_input_idxs
#    2715         )
# -> 2716         out = model(new_inputs)
#    2717
#    2718         # If a mutated tensor was cloned to be aligned, we need to reflect back the mutation to the
#
# /tmp/torchinductor_root/va/cvaw5ofgwfinpbi5lzgcplbkzkitokalpkuoxqxquuegswqbfdf4.py in call(args)
#     421         triton_poi_fused__to_copy_1.run(arg2_1, buf1, 262668288, stream=stream0)
#     422         del arg2_1
# --> 423         buf2 = empty_strided_cuda((s97, 128256), (128256, 1), torch.float16)
#     424         # Topologically Sorted Source Nodes: [logits], Original ATen: [aten.mm]
#     425         extern_kernels.mm(buf0, buf1, out=buf2)
#
# OutOfMemoryError: CUDA out of memory. Tried to allocate 1008.00 MiB. GPU 0 has a total capacity of 14.74 GiB of which 436.12 MiB is free. Process 9950 has 14.31 GiB memory in use. Of the allocated memory 14.08 GiB is allocated by PyTorch, and 84.52 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)

# %%
used_memory = round(torch.cuda.max_memory_reserved() / 1024 / 1024 / 1024, 3)
used_memory_for_lora = round(used_memory - start_gpu_memory, 3)
used_percentage = round(used_memory         /max_memory*100, 3)
lora_percentage = round(used_memory_for_lora/max_memory*100, 3)
print(f"{trainer_stats.metrics['train_runtime']} seconds used for training.")
print(f"{round(trainer_stats.metrics['train_runtime']/60, 2)} minutes used for training.")
print(f"Peak reserved memory = {used_memory} GB.")
print(f"Peak reserved memory for training = {used_memory_for_lora} GB.")
print(f"Peak reserved memory % of max memory = {used_percentage} %.")
print(f"Peak reserved memory for training % of max memory = {lora_percentage} %.")

# %% [markdown]
# # Supervised Fine-Tuning (SFT)

# %% [markdown]
# ## Datasets(s)

# %%
#@title Init datasets
datasets = {}

# %%
#@title French instruct
datasets['french_instruct'] = loadDataset('angeluriot/french_instruct', 'sft')
# Out:
# README.md: 0.00B [00:00, ?B/s]
# dataset.parquet:   0%|          | 0.00/181M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/275600 [00:00<?, ? examples/s]
# Map:   0%|          | 0/275600 [00:00<?, ? examples/s]

# %%
#@title SmolTalk Think
datasets['smaltalk-think'] = loadDataset('CATIE-AQ/smoltalk2_aya_think_dataset_french_split', 'sft', subset='french_raisonning', thinking=True)
# Out:
# README.md: 0.00B [00:00, ?B/s]
# french/train-00000-of-00001.parquet:   0%|          | 0.00/3.85M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/1393 [00:00<?, ? examples/s]
# Map:   0%|          | 0/1393 [00:00<?, ? examples/s]

# %%
#@title SmolTalk ToolCalling
datasets['smaltalk-toolcalling'] = loadDataset('CATIE-AQ/smoltalk2_smolagents_toolcalling_french', 'sft')
# Out:
# README.md:   0%|          | 0.00/968 [00:00<?, ?B/s]
# data/train-00000-of-00001.parquet:   0%|          | 0.00/82.3M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/9079 [00:00<?, ? examples/s]
# Map:   0%|          | 0/9079 [00:00<?, ? examples/s]

# %%
#@title Facebook Community
datasets['facebook'] = loadDataset('CATIE-AQ/facebook-community-alignment-dataset_french_conversation', 'sft')
# Out:
# README.md: 0.00B [00:00, ?B/s]
# data/train-00000-of-00001.parquet:   0%|          | 0.00/13.3M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/11433 [00:00<?, ? examples/s]
# Map:   0%|          | 0/11433 [00:00<?, ? examples/s]

# %%
#@title Dump datasets
dumpDatasets(datasets)
# Out:
# ========================= FRENCH_INSTRUCT =========================
# ########## TEXT
# ('<|im_start|>system\n'
#  '## Metadata\n'
#  '\n'
#  'Knowledge Cutoff Date: June 2025\n'
#  'Today Date: 29 September 2025\n'
#  'Reasoning Mode: /no_think\n'
#  '\n'
#  '## Custom Instructions\n'
#  '\n'
#  'Utilise le contexte entre <ctx> pour répondre. Si tu ne sais pas, dis-le.\n'
#  '<ctx>\n'
#  '\n'
#  '</ctx>\n'
#  '\n'
#  '<|im_start|>user\n'
#  'Une application financière omniprésente sur Mac, iOS et Windows ?<|im_end|>\n'
#  '<|im_start|>assistant\n'
#  '<think>\n'
#  '\n'
#  '</think>\n'
#  'Il existe plusieurs applications financières disponibles sur Mac, iOS et '
#  "Windows. Voici quelques exemples : Mint : il s'agit d'une application de "
#  'finances personnelles gratuite qui vous permet de suivre vos dépenses, de '
#  "créer un budget et d'obtenir des conseils personnalisés sur la façon "
#  "d'économiser de l'argent. Il est disponible sur les trois plates-formes. "
#  "Personal Capital : il s'agit d'une application de gestion financière qui "
#  'offre une gamme de fonctionnalités, notamment la budgétisation, le suivi des '
#  'investissements et la planification de la retraite. Il est disponible sur '
#  "les trois plateformes. Acorns : il s'agit d'une application d'investissement "
#  "qui vous permet de commencer à investir avec de petites sommes d'argent. Il "
#  'est disponible sur les trois plateformes. YNAB (You Need a Budget) : il '
#  "s'agit d'une application de budgétisation qui vous aide à prendre le "
#  'contrôle de votre argent et à atteindre vos objectifs financiers. Il est '
#  "disponible sur les trois plateformes.Quicken : Il s'agit d'un outil de "
#  'gestion des finances personnelles qui offre des fonctionnalités telles que '
#  'la budgétisation, le suivi des factures et le suivi des investissements. Il '
#  'est disponible sur les trois plates-formes. Il convient de noter que '
#  'certaines applications financières peuvent avoir des caractéristiques ou des '
#  'fonctionnalités différentes selon la plate-forme sur laquelle elles sont '
#  "utilisées. C'est toujours une bonne idée de faire des recherches et de "
#  'comparer différentes applications pour trouver celle qui répond le mieux à '
#  'vos besoins.<|im_end|>\n')
#
#
#
# ========================= SMALTALK-THINK =========================
# ########## TEXT
# ('<|im_start|>system\n'
#  '## Metadata\n'
#  '\n'
#  'Knowledge Cutoff Date: June 2025\n'
#  'Today Date: 29 September 2025\n'
#  'Reasoning Mode: /think\n'
#  '\n'
#  '## Custom Instructions\n'
#  '\n'
#  'You are a helpful AI assistant named SmolLM, trained by Hugging Face. Your '
#  'role as an assistant involves thoroughly exploring questions through a '
#  'systematic thinking process before providing the final precise and accurate '
#  'solutions. This requires engaging in a comprehensive cycle of analysis, '
#  'summarizing, exploration, reassessment, reflection, backtracking, and '
#  'iteration to develop well-considered thinking process. Please structure your '
#  'response into two main sections: Thought and Solution using the specified '
#  'format: <think> Thought section </think> Solution section. In the Thought '
#  'section, detail your reasoning process in steps. Each step should include '
#  'detailed considerations such as analysing questions, summarizing relevant '
#  'findings, brainstorming new ideas, verifying the accuracy of the current '
#  'steps, refining any errors, and revisiting previous steps. In the Solution '
#  'section, based on various attempts, explorations, and reflections from the '
#  'Thought section, systematically present the final solution that you deem '
#  'correct. The Solution section should be logical, accurate, and concise and '
#  'detail necessary steps needed to reach the conclusion.\n'
#  '\n'
#  '<|im_start|>user\n'
#  'Combien y a-t-il de signes de feu en astrologie ?\n'
#  '<|im_end|>\n'
#  '<|im_start|>assistant\n'
#  '<think>\n'
#  "D'accord, l'utilisateur demande combien de signes de feu il y a en "
#  'astrologie. Permettez-moi de commencer par rappeler les bases des signes du '
#  "zodiaque. Il y a 12 signes au total, chacun associé à l'un des quatre "
#  "éléments : le feu, la terre, l'air et l'eau. Chaque élément a trois signes.  "
#  'Les signes de feu sont connus pour être passionnés, énergiques et '
#  'enthousiastes. Les trois signes de feu sont le Bélier, le Lion et le '
#  'Sagittaire. Le Bélier est le premier signe, à partir du 21 mars environ, le '
#  'Lion est le cinquième, vers le 23 juillet, et le Sagittaire est le neuvième, '
#  "à partir du 22 novembre environ.   Je devrais m'assurer que je ne confonds "
#  "pas les éléments avec d'autres classifications. Parfois, les gens confondent "
#  'les éléments avec les modes (cardinal, fixe, muable), mais dans ce cas, la '
#  'question porte spécifiquement sur les éléments. Il est donc essentiel de '
#  "s'en tenir au feu en tant qu'élément.  Permettez-moi de vérifier la liste. "
#  'Le Bélier est un signe de feu, le Lion est un signe de feu et le Sagittaire '
#  'est également un signe de feu. Les autres signes sont la terre (Taureau, '
#  "Vierge, Capricorne), l'air (Gémeaux, Balance, Verseau) et l'eau (Cancer, "
#  "Scorpion, Poissons). Cela fait trois signes de feu.   Je pense que c'est "
#  'exact. Pour être complet, mentionnez peut-être chaque signe de feu et leurs '
#  "dates pour donner une réponse complète. L'utilisateur pourrait également "
#  'apprécier une brève description des traits associés aux signes de feu pour '
#  'comprendre pourquoi ils sont regroupés. Mais la réponse principale est '
#  'trois. Permettez-moi de confirmer une fois de plus pour éviter toute erreur. '
#  "Oui, trois signes de feu : Bélier, Lion, Sagittaire. C'est la norme en "
#  "astrologie occidentale. D'accord, je peux répondre en toute confiance qu'il "
#  'y a trois signes de feu.\n'
#  '\n'
#  '</think>\n'
#  '\n'
#  'En astrologie, il y a **3 signes de feu** parmi les 12 signes du zodiaque. '
#  'Les signes de feu sont :\n'
#  '\n'
#  '1. **Bélier** (21 mars - 19 avril)  \n'
#  '2. **Lion** (23 juillet - 22 août)  \n'
#  '3. **Sagittaire** (22 novembre - 21 décembre)  \n'
#  '\n'
#  'Ces signes sont associés aux éléments de **feu**, symbolisant la passion, '
#  "l'énergie, la créativité et l'enthousiasme. Chaque élément (feu, terre, air, "
#  'eau) compte 3 signes, répartis en groupes de 3 mois dans le cycle '
#  'annuel.<|im_end|>\n')
#
#
#
# ========================= SMALTALK-TOOLCALLING =========================
# ########## TEXT
# ('<|im_start|>system\n'
#  '## Metadata\n'
#  '\n'
#  'Knowledge Cutoff Date: June 2025\n'
#  'Today Date: 29 September 2025\n'
#  'Reasoning Mode: /think\n'
#  '\n'
#  '## Custom Instructions\n'
#  '\n'
#  'You are a helpful AI assistant named SmolLM, trained by Hugging Face. Your '
#  'role as an assistant involves thoroughly exploring questions through a '
#  'systematic thinking process before providing the final precise and accurate '
#  'solutions. This requires engaging in a comprehensive cycle of analysis, '
#  'summarizing, exploration, reassessment, reflection, backtracking, and '
#  'iteration to develop well-considered thinking process. Please structure your '
#  'response into two main sections: Thought and Solution using the specified '
#  'format: <think> Thought section </think> Solution section. In the Thought '
#  'section, detail your reasoning process in steps. Each step should include '
#  'detailed considerations such as analysing questions, summarizing relevant '
#  'findings, brainstorming new ideas, verifying the accuracy of the current '
#  'steps, refining any errors, and revisiting previous steps. In the Solution '
#  'section, based on various attempts, explorations, and reflections from the '
#  'Thought section, systematically present the final solution that you deem '
#  'correct. The Solution section should be logical, accurate, and concise and '
#  'detail necessary steps needed to reach the conclusion.\n'
#  '\n'
#  '### Tools\n'
#  '\n'
#  'You may call one or more functions to assist with the user query.\n'
#  'You are provided with function signatures within <tools></tools> XML tags:\n'
#  '\n'
#  '<tools>\n'
#  '{"type": "function", "function": {"name": "final_answer", "description": '
#  '"Provides a final answer to the given problem.", "parameters": {"type": '
#  '"object", "properties": {"answer": {"type": "string", "description": "The '
#  'final answer to the problem"}}, "required": ["answer"]}}}\n'
#  '{"type": "function", "function": {"name": "web_search", "description": '
#  '"Performs a web search for a query and returns a string of the top search '
#  'results formatted as markdown with titles, links, and descriptions.", '
#  '"parameters": {"type": "object", "properties": {"query": {"type": "string", '
#  '"description": "The search query to perform."}}, "required": ["query"]}}}\n'
#  '{"type": "function", "function": {"name": "wikipedia_search", "description": '
#  '"Searches Wikipedia and returns a summary or full text of the given topic, '
#  'along with the page URL.", "parameters": {"type": "object", "properties": '
#  '{"query": {"type": "string", "description": "The topic to search on '
#  'Wikipedia."}}, "required": ["query"]}}}\n'
#  '</tools>\n'
#  '\n'
#  'For each function call, return a json object with function name and '
#  'arguments within <tool_call></tool_call> XML tags:\n'
#  '<tool_call>\n'
#  '{"name": <function-name>, "arguments": <args-json-object>}\n'
#  '</tool_call>\n'
#  '\n'
#  '<|im_end|>\n'
#  '<|im_start|>user\n'
#  'Le modèle logistique a été appliqué à la croissance naturelle de la '
#  "population de flétan dans certaines zones de l'océan Pacifique. ${ }^{12}$ "
#  'Soit $y$, mesurée en kilogrammes, la masse totale, ou biomasse, de la '
#  'population de flétan au temps $t$. On estime que les paramètres de '
#  "l'équation logistique ont les valeurs $r=0,71 /$ an et $K=80,5 \\times 10^6 "
#  '\\mathrm{~kg}$. Si la biomasse initiale est $y_0=0,25 K$, trouvez la '
#  'biomasse 2 ans plus tard.  Réponse avec seulement le nombre final en $10^6 '
#  '\\mathrm{~kg}$ unité.\n'
#  '<|im_end|>\n'
#  '<|im_start|>assistant\n'
#  "<think>I've calculated the biomass at t = 2 years using the logistic growth "
#  'formula with the given parameters and initial condition, arriving at an '
#  "answer of 46.7 in $10^6$ kg units. Now I'll output this as the final "
#  'answer.</think>\n'
#  "<tool_call>{'name': 'final_answer', 'arguments': {'answer': '46.7\n"
#  "'}}</tool_call><|im_end|>\n")
#
#
#
# ========================= FACEBOOK =========================
# ########## TEXT
# ('<|im_start|>system\n'
#  '## Metadata\n'
#  '\n'
#  'Knowledge Cutoff Date: June 2025\n'
#  'Today Date: 29 September 2025\n'
#  'Reasoning Mode: /no_think\n'
#  '\n'
#  '## Custom Instructions\n'
#  '\n'
#  'You are a helpful AI assistant named SmolLM, trained by Hugging Face.\n'
#  '\n'
#  '<|im_start|>user\n'
#  'Je vais assister à la fête d’anniversaire des 5 ans de ma nièce et je '
#  'souhaite écrire un message sur une carte-cadeau, en mentionnant que je me '
#  'suis entraîné·e à chanter sa comptine pour enfants préférée et en suggérant '
#  'que nous la chantions ensemble pendant la fête.<|im_end|>\n'
#  '<|im_start|>assistant\n'
#  '<think>\n'
#  '\n'
#  '</think>\n'
#  '"Joyeux 5 ans, ma chère nièce ! Je me suis entraîné·e à chanter ta comptine '
#  "pour enfants préférée. Allons la chanter ensemble aujourd'hui ! Je "
#  't\'aime."<|im_end|>\n'
#  '<|im_start|>user\n'
#  'Quel cadeau je pourrais lui offrir ?<|im_end|>\n'
#  '<|im_start|>assistant\n'
#  '<think>\n'
#  '\n'
#  '</think>\n'
#  "Une expérience, telle qu'un ticket pour un parc d'attractions, un spectacle "
#  'pour enfants, ou une séance de peinture, peut créer des souvenirs '
#  "inoubliables pour votre nièce. C'est une façon unique de célébrer son "
#  'anniversaire et de partager du temps de qualité ensemble.<|im_end|>\n')

# %%
#@title Merge datasets
dataset = mergeDatasets(datasets)
# Out:
# ========================= SMALTALK-THINK =========================
# ########## TEXT
# ('<|im_start|>user\n'
#  'Comment s’appelle la partie solide située au centre de la Terre ?<|im_end|>\n'
#  '<|im_start|>assistant\n'
#  '<think>\n'
#  "D'accord, l'utilisateur pose des questions sur la partie solide au centre de "
#  'la Terre. Permettez-moi de réfléchir. Je me souviens que la Terre a des '
#  'couches. La couche la plus externe est la croûte, puis le manteau, qui est '
#  "principalement solide mais peut s'écouler lentement. Ensuite, il y a le "
#  "noyau externe, qui est liquide, n'est-ce pas ? Et le noyau interne est "
#  'solide. Ainsi, le centre solide serait le noyau interne.  Attendez, le noyau '
#  "interne est-il vraiment solide ? Je pense qu'il est sous une pression si "
#  "élevée que même s'il fait extrêmement chaud, la pression le maintient "
#  'solide. Le noyau externe est liquide car la pression y est plus faible, ce '
#  "qui permet au fer et au nickel de rester à l'état liquide. La réponse "
#  'devrait donc être le noyau interne. Permettez-moi de vérifier cela. Oui, la '
#  'structure de la Terre est constituée de croûte, de manteau, de noyau externe '
#  '(liquide), de no')
#
#
#
# ========================= SMALTALK-TOOLCALLING =========================
# ########## TEXT
# ('<|im_start|>user\n'
#  'Quelle version du logiciel 7-Zip incluait la note de mise à jour « 7-Zip '
#  'peut désormais décompresser les archives DMG qui utilisent la méthode de '
#  'compression LZFSE. » avec sa sortie ?\n'
#  '<|im_end|>\n'
#  '<|im_start|>assistant\n'
#  '<think>I need to gather reliable information about Mozilla Thunderbird '
#  'security vulnerabilities specifically from 2018, so performing a targeted '
#  'web search should help me locate relevant sources or databases summarizing '
#  'these vulnerabilities.</think>\n'
#  "<tool_call>{'name': 'web_search', 'arguments': {'query': 'Mozilla "
#  "Thunderbird security vulnerabilities 2018'}}</tool_call><|im_end|>\n"
#  '<|im_start|>system\n'
#  'Observation:\n'
#  '## Search Results\n'
#  '0. [Security Advisories for Thunderbird - '
#  'Mozilla](https://www.mozilla.org/en-US/security/known-vulnerabilities/thunderbird/)\n'
#  '\n'
#  'Low Minor security vulnerabilities such as Denial of Service attacks, minor '
#  'data leaks, or spoofs. (Undetectable spoofs of SSL indicia would have "High" '
#  'impact ...\n'
#  '\n'
#  '1. [Security vulnerabilities fixed in Thunderbird 52.9 - Mozilla')

# %% [markdown]
# ## Training

# %% [markdown]
# ### Setup Trainer

# %%
from trl import SFTTrainer
from transformers import TrainingArguments
from unsloth import is_bfloat16_supported

trainer = SFTTrainer(
    model = model,
    tokenizer = tokenizer,
    train_dataset = dataset,
    dataset_text_field = "text",
    max_seq_length = max_seq_length,
    dataset_num_proc = dataset_processors,
    packing = False, # Can make training 5x faster for short sequences.
    args = TrainingArguments(
        per_device_train_batch_size = 2,
        gradient_accumulation_steps = 8,
        warmup_steps = 5,
        max_steps = 60 if debug else -1, # None for full run
        num_train_epochs = 0 if debug else 1,
        learning_rate = 2e-4, # Lower for slower but more precise fine-tuning. Try values like 1e-4, 5e-5, or 2e-5
        fp16 = not is_bfloat16_supported(),
        bf16 = is_bfloat16_supported(),
        logging_steps = 1,
        optim = "adamw_8bit",
        weight_decay = 0.01,
        lr_scheduler_type = "linear",
        seed = 3407,
        output_dir = "outputs",
        report_to = "none", # remove to activate WandDB
    ),
)

# %% [markdown]
# ### Training Execution
# Execute the training process with the configured trainer and monitor the training progress.

# %%
gpu_stats = torch.cuda.get_device_properties(0)
start_gpu_memory = round(torch.cuda.max_memory_reserved() / 1024 / 1024 / 1024, 3)
max_memory = round(gpu_stats.total_memory / 1024 / 1024 / 1024, 3)
print(f"GPU = {gpu_stats.name}. Max memory = {max_memory} GB.")
print(f"{start_gpu_memory} GB of memory reserved.")

# %%
trainer_stats = trainer.train()

# %%
used_memory = round(torch.cuda.max_memory_reserved() / 1024 / 1024 / 1024, 3)
used_memory_for_lora = round(used_memory - start_gpu_memory, 3)
used_percentage = round(used_memory         /max_memory*100, 3)
lora_percentage = round(used_memory_for_lora/max_memory*100, 3)
print(f"{trainer_stats.metrics['train_runtime']} seconds used for training.")
print(f"{round(trainer_stats.metrics['train_runtime']/60, 2)} minutes used for training.")
print(f"Peak reserved memory = {used_memory} GB.")
print(f"Peak reserved memory for training = {used_memory_for_lora} GB.")
print(f"Peak reserved memory % of max memory = {used_percentage} %.")
print(f"Peak reserved memory for training % of max memory = {lora_percentage} %.")

# %% [markdown]
# # Direct Preference Optimization (DPO)

# %% [markdown]
# ## Datasets

# %%
#@title Init datasets
datasets = {}

# %%
#@title French ORCA DPO
datasets['french-orca-dpo'] = loadDataset('jpacifico/french-orca-dpo-pairs-revised', 'dpo')

# %%
#@title Aya French
if False: datasets['aya-french'] = loadDataset('CATIE-AQ/aya_french_dpo', 'dpo')

# %%
#@title Dump datasets
dumpDatasets(datasets)

# %%
#@title Merge datasets
dataset = mergeDatasets(datasets)

# %% [markdown]
# ## Training

# %% [markdown]
# ### Setup Trainer

# %%
# Enable reward modelling stats
from unsloth import PatchDPOTrainer
PatchDPOTrainer()
from transformers import TrainingArguments
from trl import DPOTrainer, DPOConfig
from unsloth import is_bfloat16_supported

dpo_trainer = DPOTrainer(
    model = model,
    ref_model = None,
    beta = 0.1,
    train_dataset = dataset,
    tokenizer = tokenizer,
    max_length = 4096,
    max_prompt_length = 2048,
    dataset_num_proc = dataset_processors,
    args = DPOConfig(
        per_device_train_batch_size = 2,
        gradient_accumulation_steps = 4,
        warmup_steps = 5,
        max_steps = 60 if debug else -1, # None for full run
        num_train_epochs = 0 if debug else 1,
        learning_rate = 2e-4, # Lower for slower but more precise fine-tuning. Try values like 1e-4, 5e-5, or 2e-5
        fp16 = not is_bfloat16_supported(),
        bf16 = is_bfloat16_supported(),
        logging_steps = 1,
        optim = "adamw_8bit",
        weight_decay = 0.01,
        lr_scheduler_type = "linear",
        seed = 42,
        output_dir = "outputs",
        report_to = "none", # remove to activate WandDB
    ),
)

# %% [markdown]
# ### Training Execution
# Execute the training process with the configured trainer and monitor the training progress.

# %%
gpu_stats = torch.cuda.get_device_properties(0)
start_gpu_memory = round(torch.cuda.max_memory_reserved() / 1024 / 1024 / 1024, 3)
max_memory = round(gpu_stats.total_memory / 1024 / 1024 / 1024, 3)
print(f"GPU = {gpu_stats.name}. Max memory = {max_memory} GB.")
print(f"{start_gpu_memory} GB of memory reserved.")

# %%
dpo_trainer.train()

# %%
used_memory = round(torch.cuda.max_memory_reserved() / 1024 / 1024 / 1024, 3)
used_memory_for_lora = round(used_memory - start_gpu_memory, 3)
used_percentage = round(used_memory         /max_memory*100, 3)
lora_percentage = round(used_memory_for_lora/max_memory*100, 3)
print(f"Peak reserved memory = {used_memory} GB.")
print(f"Peak reserved memory for training = {used_memory_for_lora} GB.")
print(f"Peak reserved memory % of max memory = {used_percentage} %.")
print(f"Peak reserved memory for training % of max memory = {lora_percentage} %.")

# %% [markdown]
# # Testing (inference)
# Let's run the model! You can change the instruction and input - leave the output blank!

# %%
from unsloth.chat_templates import get_chat_template

tokenizerInference = get_chat_template(
    tokenizer,
    chat_template = "chatml", # Supports zephyr, chatml, mistral, llama, alpaca, vicuna, vicuna_old, unsloth
    map_eos_token = True, # Maps <|im_end|> to </s> instead
)

FastLanguageModel.for_inference(model) # Enable native 2x faster inference

messages = [
    {"role": "user", "content": "Continue the fibonnaci sequence: 1, 1, 2, 3, 5, 8,"},
]
inputs = tokenizer.apply_chat_template(
    messages,
    tokenizerInference = True,
    add_generation_prompt = True, # Must add for generation
    return_tensors = "pt",
).to("cuda")

outputs = model.generate(input_ids = inputs, max_new_tokens = 64, use_cache = True)
tokenizerInference.batch_decode(outputs)

# %% [markdown]
#  You can also use a `TextStreamer` for continuous inference - so you can see the generation token by token, instead of waiting the whole time!

# %%
FastLanguageModel.for_inference(model) # Enable native 2x faster inference

messages = [
    {"role": "user", "content": "Continue the fibonnaci sequence: 1, 1, 2, 3, 5, 8,"},
    #{"role": "user", "content": "Quel est la fameuse grande tour à Paris?"},
]
inputs = tokenizerInference.apply_chat_template(
    messages,
    tokenize = True,
    add_generation_prompt = True, # Must add for generation
    return_tensors = "pt",
).to("cuda")

from transformers import TextStreamer
text_streamer = TextStreamer(tokenizerInference)
_ = model.generate(input_ids = inputs, streamer = text_streamer, max_new_tokens = 128, use_cache = True)

# %% [markdown]
# # Saving

# %% [markdown]
# ## Create HF repository

# %%
from huggingface_hub import HfApi

if save_hf:
  hf_api = HfApi(token=hf_token)
  hf_api.create_repo(repo_id = hf_username + "/" + model_name, repo_type = "model", private = True, exist_ok = True)
  hf_api.create_repo(repo_id = hf_username + "/" + model_name + "-GGUF", repo_type = "model", private = True, exist_ok = True)

# %% [markdown]
# ## Saving to float16 for VLLM (safetensors)
#
# We also support saving to `float16` directly. Select `merged_16bit` for float16 or `merged_4bit` for int4. We also allow `lora` adapters as a fallback. Use `push_to_hub_merged` to upload to your Hugging Face account! You can go to https://huggingface.co/settings/tokens for your personal tokens.

# %%
model.save_pretrained_merged(model_name, tokenizer)
if save_hf: model.push_to_hub_merged(hf_username + "/" + model_name, token = hf_token)
# Out:
# Found HuggingFace hub cache directory: /home/unsloth/.cache/huggingface/hub
# Fetching 1 files:   0%|          | 0/1 [00:00<?, ?it/s]
# Checking cache directory for required files...
# Successfully copied all 2 files from cache to Claire-3B-v0.2.0.
# Unsloth: Preparing safetensor model files: 100%|██████████| 2/2 [00:00<00:00, 33288.13it/s]
# Unsloth: Merging weights into 16bit: 100%|██████████| 2/2 [02:55<00:00, 87.71s/it]
# Unsloth: Merge process complete.

# %% [markdown]
# ## GGUF / llama.cpp Conversion
# To save to `GGUF` / `llama.cpp`, we support it natively now! We clone `llama.cpp` and we default save it to `q8_0`. We allow all methods like `q4_k_m`. Use `save_pretrained_gguf` for local saving and `push_to_hub_gguf` for uploading to HF.
#
# Some supported quant methods (full list on our [Wiki page](https://github.com/unslothai/unsloth/wiki#gguf-quantization-options)):
# * `q8_0` - Fast conversion. High resource use, but generally acceptable.
# * `q4_k_m` - Recommended. Uses Q6_K for half of the attention.wv and feed_forward.w2 tensors, else Q4_K.
# * `q5_k_m` - Recommended. Uses Q6_K for half of the attention.wv and feed_forward.w2 tensors, else Q5_K.

# %%
model.save_pretrained_gguf(model_name, tokenizer, quantization_method = quantizations)

if save_hf:
  for quant in quantizations:
    hf_api.upload_file(
      path_or_fileobj=model_name + "." + quant.upper() + ".gguf",
      path_in_repo=model_name + "-" + quant.upper() + ".gguf",
      repo_id=hf_username + "/" + model_name + "-GGUF"
    )
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 model.save_pretrained_gguf(model_name, tokenizer, quantization_method = ["q4_k_m"])
#       3 if save_hf:
#       4   for quant in quantizations:
#
# File /opt/conda/lib/python3.11/site-packages/torch/utils/_contextlib.py:116, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     113 @functools.wraps(func)
#     114 def decorate_context(*args, **kwargs):
#     115     with ctx_factory():
# --> 116         return func(*args, **kwargs)
#
# File /opt/conda/lib/python3.11/site-packages/unsloth/save.py:2326, in save_to_gguf_generic(model, save_directory, tokenizer, quantization_method, quantization_type, repo_id, token)
#    2323 # Go through all types and save individually - somewhat inefficient
#    2324 # since we save F16 / BF16 multiple times
#    2325 for quantization_type in new_quantization_methods:
# -> 2326     metadata = _convert_to_gguf(
#    2327         save_directory,
#    2328         print_output = True,
#    2329         quantization_type = quantization_type,
#    2330     )
#    2331     if repo_id is not None:
#    2332         prepare_saving(
#    2333             model,
#    2334             repo_id,
#    (...)   2338             token = token,
#    2339         )
#
# File /opt/conda/lib/python3.11/site-packages/unsloth_zoo/llama_cpp.py:677, in convert_to_gguf(input_folder, output_filename, quantization_type, max_shard_size, print_output, print_outputs)
#     665 def convert_to_gguf(
#     666     input_folder,
#     667     output_filename = None,
#    (...)    673     # All Unsloth Zoo code licensed under LGPLv3
#     674     # Converts to GGUF using convert_hf_to_gguf.py directly!
#     676     max_shard_size = check_max_shard_size(max_shard_size)
# --> 677     quantization_type, _ = check_quantization_type(quantization_type)
#     679     if not os.path.exists(input_folder):
#     680         raise RuntimeError(f"Unsloth: `{input_folder}` does not exist?")
#
# File /opt/conda/lib/python3.11/site-packages/unsloth_zoo/llama_cpp.py:638, in check_quantization_type(quantization_type)
#     636 SUPPORTED_GGUF_TYPES = frozenset(("f32", "f16", "bf16", "q8_0"))
#     637 if quantization_type not in SUPPORTED_GGUF_TYPES:
# --> 638     raise RuntimeError(
#     639         f"Unsloth: `{quantization_type}` quantization type is not supported.\n"\
#     640         f"The following quantization types are supported: `{list(SUPPORTED_GGUF_TYPES)}`"
#     641     )
#     642 pass
#     643 size_multiplier = {
#     644     "q8_0" : 0.5,
#     645     "f32"  : 2.0,
#     646     "f16"  : 1.0,
#     647     "bf16" : 1.0,
#     648 }
#
# RuntimeError: Unsloth: `q4_k_m` quantization type is not supported.
# The following quantization types are supported: `['f16', 'q8_0', 'f32', 'bf16']`
